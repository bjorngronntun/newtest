# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from math import factorial

# %%
def S(x, n):
    term = sum((-1)**j*(x**(2*j + 1))/(factorial(2*j + 1)) for j in range(n + 1))
    return term

# %%
x = np.linspace(0, 4*np.pi, 1000)
'''
y = np.zeros(len(x))
for i in range(len(x)):
    y[i] = S(x[i],1)
plt.plot(x, y)
for i in range(len(x)):
    y[i] = S(x[i],2)
plt.plot(x, y)
for i in range(len(x)):
    y[i] = S(x[i],12)
plt.plot(x, y)

'''
plt.plot(x, S(x, 1), label = 'n=1')
plt.plot(x, S(x, 2), label = 'n=2')
plt.plot(x, S(x, 3), label = 'n=3')
plt.plot(x, S(x, 6), label = 'n=6')
plt.plot(x, S(x, 12), label = 'n=12')
plt.plot(x, np.sin(x), label = 'Sine function')
plt.legend()
plt.show()
print(S(np.pi/2,8))
# Out:
# 1.0000000000000437
